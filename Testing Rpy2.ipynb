# %%
import rpy2.robjects as robjects

# %%
# %load_ext rpy2.ipython

# %%
# %R require(ggplot2)
# Out:
# /anaconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# array([1], dtype=int32)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Letter': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                   'X': [4, 3, 5, 2, 1, 7, 7, 5, 9],
                   'Y': [0, 4, 3, 6, 7, 10, 11, 9, 13],
                   'Z': [1, 2, 3, 1, 2, 3, 1, 2, 3]})

# %%
# %%R -i df
# ggplot(data = df) + geom_point(aes(x = X, y = Y, color = Letter, size = Z))
